# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn

df = pd.read_csv('out.csv')  
df.head()
# Out:
#    session  trial  phrase  click_load  correction_rate  num_chars
# 0        1      0       1         6.8              0.0          7
# 1        1      0       2         8.2              0.0          7
# 2        2      0       1         8.0              0.0          7
# 3        2      0       2         6.2              0.0          7
# 4        2      0       3         4.6              0.0          7

# %%
sns.lineplot(data=d)
# Out:
#    session  trial  phrase  click_load  correction_rate  num_chars
# 0        1      0       1         6.8              0.0          7
# 1        1      0       2         8.2              0.0          7
# 2        2      0       1         8.0              0.0          7
# 3        2      0       2         6.2              0.0          7
# 4        2      0       3         4.6              0.0          7
